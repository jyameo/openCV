# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
image =  cv2.imread("/root/openCV/bin/im_test")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print("Shape: {}".format(image.shape))
print("Width: {} pixels".format(image.shape[1]))
print("Height: {} pixels".format(image.shape[0]))
print("Channels: {} pixels".format(image.shape[2]))

plt.imshow(image)
plt.show()
# Out:
# Shape: (460, 460, 3)
# Width: 460 pixels
# Height: 460 pixels
# Channels: 3 pixels

# %% [markdown]
# # Average Blurring

# %%
blurred = np.hstack([
    cv2.blur(image, (3,3)),
    cv2.blur(image, (7,7)),
    cv2.blur(image, (9,9))])

# %%
plt.imshow(blurred)
plt.show()

# %% [markdown]
# # Gaussian Blurring

# %%
g_blurred = np.hstack([
    cv2.GaussianBlur(image, (3,3), 0),
    cv2.GaussianBlur(image, (7,7), 0),
    cv2.GaussianBlur(image, (9,9), 0)])

# %%
plt.imshow(g_blurred)
plt.show()

# %% [markdown]
# # Median Blurring

# %%
m_blurred = np.hstack([
    cv2.medianBlur(image, 3),
    cv2.medianBlur(image, 7),
    cv2.medianBlur(image, 9)])

# %%
plt.imshow(m_blurred)
plt.show()

# %% [markdown]
# # Bilateral Filter

# %%
bf_blurred = np.hstack([
    cv2.bilateralFilter(image, 3, 21, 21),
    cv2.bilateralFilter(image, 7, 31, 31),
    cv2.bilateralFilter(image, 9, 51, 51)])

# %%
plt.imshow(bf_blurred)
plt.show()
